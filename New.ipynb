# %% [markdown]
# ### Create a class named 'Data', create an init method with variable, 'file_name', 'file_type', 'date', 'size'. Create a function named 'file_open()' which will take file name and create file in your local if not exists and write something in the file. Create another function which will take file_name and read data and return. Create another file named 'file_append()' and append new data in same file and show.
#
# ### Implement i) Exception handling, ii) Logger by creating a separate method which will act as logging, iii) Description

# %%
import os
import logging as lg
import datetime

class Data:
    '''
    This class is for OOPs operation with file handling
    ===================================================
    We need to pass file_name, file_type, date and size
    to perforn write, read and append operations.
    '''
    try:
        def __init__(self, file_name, file_type, date, size):
            '''
            This is the constructor to initialize the variables
            '''
            self.data_log("Variable initializing")
            self.file_name = file_name
            self.file_type = file_type
            self.date = date
            self.size = size
            
    except Exception as e:
        self.data_log(e)
        print(e)
        
    try:
        def file_open(self):
            '''
            File creation and writing data to it wheather the input type is 
            list, dict, tuple or individual file
            '''
            self.data_log("File creation and writing data")
            if type(self.file_name) == list:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'w') as file:
                        file.write(f'This is a text file\nCreated on {self.date}\nWith size {self.size} passed as list')
            elif type(self.file_name) == dict:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'w') as file:
                        file.write(f'This is a text file\nCreated on {self.date}\nWith size {self.size} passed as dict')
            elif type(self.file_name) == tuple:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'w') as file:
                        file.write(f'This is a text file\nCreated on {self.date}\nWith size {self.size} passed as tuple')
            else:
                with open(f"{self.file_name}.{self.file_type}", 'w') as file:
                    file.write(f'This is a text file\nCreated on {self.date}\nWith size {self.size}')
    
    except Exception as e:
        self.data_log(e)
        print(e)
            
    try:
        def file_read(self):
            '''
            Reading files 
            '''
            self.data_log("Reading data")
            if type(self.file_name) == list:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'r') as file:
                        print(file.read())
                        return file.read
            elif type(self.file_name) == dict:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'r') as file:
                        print(file.read())
                        return file.read
            elif type(self.file_name) == tuple:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'r') as file:
                        print(file.read())
                        return file.read
            else:
                with open(f"{self.file_name}.{self.file_type}", 'r') as file:
                    print(file.read())
                    return file.read
            
            
    except Exception as e:
        self.data_log(e)
        print(e)
        
    def __str__(self):
        '''
        This is the string description of the class
        '''
        self.data_log("String file")
        return 'This is Object oriented programming'
    try:
        def file_append(self):
            '''
            This function is for append operation
            '''
            self.data_log("Appending new data to the file then reading data")
            if type(self.file_name) == list:
                for i in file_name:
                    with open(f"{self.i}.{self.file_type}", 'a+') as file:
                        file.write('\n------------------------')
                        file.write('\nThis is new data for list')
                        print(file.read())
            elif type(self.file_name) == dict:
                for i in file_name:
                    for i in file_name:
                        with open(f"{self.i}.{self.file_type}", 'a+') as file:
                            file.write('\n------------------------')
                            file.write('\nThis is new data for dict')
                            print(file.read())
            elif type(self.file_name) == tuple:
                for i in file_name:
                    for i in file_name:
                        with open(f"{self.i}.{self.file_type}", 'a+') as file:
                            file.write('\n------------------------')
                            file.write('\nThis is new data for tuple')
                            print(file.read())
            else:
                with open(f"{self.file_name}.{self.file_type}", 'a+') as file:
                    file.write('\n------------------------')
                    file.write('\nThis is new data')
                    print(file.read())
                
    except Exception as e:
        self.data_log(e)
            
            
    def data_log(self, log):
        '''
        This function takes log as argument and stores it in a log file 
        '''
        lg.basicConfig(filename="log_file.log", level= lg.INFO,)
        lg.info(log)
    
d = Data('test10', 'txt', '05/12/2022', '2MB')
d.file_open()
d.file_read()
d.file_append()
print(d)
# Out:
# This is a text file
# Created on 05/12/2022
# With size 2MB
#
# This is Object oriented programming
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 134, in <module>
#     d = Data('test10', 'txt', '05/12/2022', '2MB')
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 18, in __init__
#     self.data_log("Variable initializing")
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 132, in data_log
#     lg.info(log)
# Message: 'Variable initializing'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 135, in <module>
#     d.file_open()
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 34, in file_open
#     self.data_log("File creation and writing data")
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 132, in data_log
#     lg.info(log)
# Message: 'File creation and writing data'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 136, in <module>
#     d.file_read()
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 60, in file_read
#     self.data_log("Reading data")
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 132, in data_log
#     lg.info(log)
# Message: 'Reading data'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 137, in <module>
#     d.file_append()
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 97, in file_append
#     self.data_log("Appending new data to the file then reading data")
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 132, in data_log
#     lg.info(log)
# Message: 'Appending new data to the file then reading data'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Sai\anaconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Sai\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Sai\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Sai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 138, in <module>
#     print(d)
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 90, in __str__
#     self.data_log("String file")
#   File "C:\Users\Sai\AppData\Local\Temp\ipykernel_12772\1307661159.py", line 132, in data_log
#     lg.info(log)
# Message: 'String file'
# Arguments: ()

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Sai\\test1'

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Sai'

# %%
cd C:\Users\Sai\test1
# Out:
# C:\Users\Sai\test1
